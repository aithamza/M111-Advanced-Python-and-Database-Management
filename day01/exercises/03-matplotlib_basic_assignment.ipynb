# %% [markdown]
# # Matplotlib exercices

# %% [markdown]
# In this exercise, we are using Pandas and Matplotlib to visualize Company Sales Data. The data is located under the folder `../data/company_sales_data.csv`.
#
# ![company_sales_data](../data/company_sales_data.webp)

# %% [markdown]
# ## Exercise 1
# **Read Total profit of all months and show it using a line plot**
#
# Total profit data provided for each month. Generated line plot must include the following properties:
# - X label name = Month Number
# - Y label name = Total profit
# The line plot graph should look like this.
#
# **Expected output**
#
# <img src="../data/Company_profit_per_month.png" alt="Company_profit_per_month" style="width: 500px;"/>

# %%
# Write your code here
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

data = pd.read_csv('C://Users//pc//OneDrive//Bureau//M111-Advanced-Python-and-Database-Management//day01//data//company_sales_data.csv')
x = data['month_number']
y = data['total_profit']
plt.figure()
plt.plot(x,y)
plt.xlabel("Month Number")
plt.ylabel("Profit in dollar")
plt.title("company profit for month")
plt.show()

# %% [markdown]
# ## Exercise 2
# **Get total profit of all months and show line plot with the following Style properties**
# - Line Style dotted and Line-color should be red
# - Show legend at the lower right location.
# - X label name = Month Number
# - Y label name = Sold units number
# - Add a circle marker.
# - Line marker color as read
# - Line width should be 3
#
# **Expected output**
#
# <img src="../data/company_sales_data_of_last_year.png" alt="company_sales_data_of_last_year" style="width: 700px;"/>

# %%
# write your code here
plt.figure()
plt.plot(x, y, label="profit data of last year", linestyle='dotted', color = 'red', linewidth=3, markersize=12)
plt.xlabel("Month Number")
plt.ylabel("Profit in dollar")
plt.title("company profit for month")
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ## Exercise 3
# **Read all product sales data and show it  using a multiline plot**
# Display the number of units sold per month for each product using multiline plots. (i.e., Separate Plotline for each product ).
# **Expected output**
#
# <img src="../data/sales_data.png" alt="sales_data" style="width: 500px;"/>

# %%
# write your code here
y1 = data.iloc[:,1:len(data)] 
y1
# Out:
#     facecream  facewash  toothpaste  bathingsoap  shampoo  moisturizer  \
# 0        2500      1500        5200         9200     1200         1500
# 1        2630      1200        5100         6100     2100         1200
# 2        2140      1340        4550         9550     3550         1340
# 3        3400      1130        5870         8870     1870         1130
# 4        3600      1740        4560         7760     1560         1740
# 5        2760      1555        4890         7490     1890         1555
# 6        2980      1120        4780         8980     1780         1120
# 7        3700      1400        5860         9960     2860         1400
# 8        3540      1780        6100         8100     2100         1780
# 9        1990      1890        8300        10300     2300         1890
# 10       2340      2100        7300        13300     2400         2100
# 11       2900      1760        7400        14400     1800         1760
#
#     total_units  total_profit
# 0         21100        211000
# 1         18330        183300
# 2         22470        224700
# 3         22270        222700
# 4         20960        209600
# 5         20140        201400
# 6         29550        295500
# 7         36140        361400
# 8         23400        234000
# 9         26670        266700
# 10        41280        412800
# 11        30020        300200

# %%
cols = y1.columns

#plt.xlim(0,15, 1)

f = plt.figure()
f.set_figwidth(12)
f.set_figheight(6)
#plt.ylim(0,800000, 12)
for i in cols[:-1]:
    plt.plot(x, y1[i],'o-', label=i )
    plt.xlabel("Month Number") 
    plt.ylabel('sales units number') 
    plt.title("sales data") 
    plt.legend(loc="upper left") 
 
    
plt.show()

# %% [markdown]
# ## Exercise 4
# **Read toothpaste sales data of each month and show it using a scatter plot**
# Also, add a grid in the plot. gridline style should “–“.
#
# **Expected output**
#
# <img src="../data/Tooth_paste_Sales_data.png" alt="sales_data" style="width: 700px;"/>

# %%
# write your code here
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
data = pd.read_csv('C://Users//pc//OneDrive//Bureau//M111-Advanced-Python-and-Database-Management//day01//data//company_sales_data.csv')
x = data['month_number']
y = data['toothpaste']
x = range(1,13)
plt.figure(figsize=(13, 5))
plt.scatter(x,y, label = 'tooth paste sales data')
plt.grid(True, linewidth= 1, linestyle="--")
plt.xlabel('Month Number')
plt.ylabel('Number of units Sold')
plt.legend(loc='upper left')
plt.title(' Tooth paste Sales data')
# Out:
# Text(0.5, 1.0, ' Tooth paste Sales data')

# %% [markdown]
# ## Exercise 5
# **Read face cream and facewash product sales data and show it using the bar chart**
# The bar chart should display the number of units sold per month for each product. Add a separate bar for each product in the same chart.
#
# **Expected output**
#
# <img src="../data/Facewash_and_facecream_sales_data.png" alt="sales_data" style="width: 700px;"/>

# %%
# write your code here
data = pd.read_csv('C://Users//pc//OneDrive//Bureau//M111-Advanced-Python-and-Database-Management//day01//data//company_sales_data.csv')
x = data['month_number']
y = data['facewash']
z = data['facecream']
plt.figure(figsize=(12, 4))

plt.bar(x - 0.2, z, width= 0.4, label = 'Face Cream sales data')
plt.bar(x + 0.2, y, width= 0.4, label = 'Face Wash sales data')
plt.xlabel('Month Number')
plt.ylabel('Sales units in number')
plt.legend(loc='upper left')
plt.title('Facewash and facecream sales data')
plt.grid(True, linewidth= 1, linestyle="--")
plt.xticks(x)
plt.ylim(0,5000)
# Out:
# (0.0, 5000.0)

# %% [markdown]
# ## Exercise 6
# **Read sales data of bathing soap of all months and show it using a bar chart. Save this plot to your hard disk**
#
# **Expected output**
#
# <img src="../data/sales_data_of_bathingsoap.png" alt="sales_data_of_bathingsoap" style="width: 700px;"/>

# %%
# write your code here
data = pd.read_csv('C://Users//pc//OneDrive//Bureau//M111-Advanced-Python-and-Database-Management//day01//data//company_sales_data.csv')
x = data['month_number']
y = data['bathingsoap']

plt.figure(figsize=(12, 4))

plt.bar(x, z, width= 0.8, label = 'bathingsoap data')
plt.xlabel('Month Number')
plt.ylabel('Sales units in number')
plt.legend(loc='upper left')
plt.title('bathingsoap sales data')
plt.grid(True, linewidth= 1, linestyle="--")
plt.xticks(x)
plt.ylim(0,5000)
# Out:
# (0.0, 5000.0)

# %% [markdown]
# ## Exercise 7
# **Read the total profit of each month and show it using the histogram to see the most common profit ranges**
#
# **Expected output**
#
# <img src="../data/Profit_data.png" alt="Profit_data" style="width: 700px;"/>

# %%
# write your code here
# write your code here
data = pd.read_csv('C://Users//pc//OneDrive//Bureau//M111-Advanced-Python-and-Database-Management//day01//data//company_sales_data.csv')
x = data['month_number']
y = data['total_profit']

plt.figure(figsize=(12, 4))

fig, axis = plt.subplots(figsize =(10, 5))
axis.hist(data['total_profit'],label = 'Profit data', bins = [150000, 175000, 200000, 225000, 250000, 300000,350000])
plt.xlabel('Profit range in dollar')
plt.ylabel('Actual profit')
plt.legend(loc='upper left')
plt.title('Profit data')
# Displaying the graph
plt.show()

# %% [markdown]
# ## Exercise 8
# **Calculate total sale data for last year for each product and show it using a Pie chart**
#
# *Note: In Pie chart display Number of units sold per year for each product in percentage.*
#
# **Expected output**
#
# <img src="../data/sales_data_pi_chart.png" alt="sales_data_pi_chart" style="width: 700px;"/>

# %%
# write your code here
df = pd.read_csv('C://Users//pc//OneDrive//Bureau//M111-Advanced-Python-and-Database-Management//day01//data//company_sales_data.csv')

monthList  = df ['month_number'].tolist()
plt.figure(figsize=(12, 4))

labels = ['FaceCream', 'FaseWash', 'ToothPaste', 'Bathing soap', 'Shampoo', 'Moisturizer']
salesData   = [df ['facecream'].sum(), df ['facewash'].sum(), df ['toothpaste'].sum(), 
         df ['bathingsoap'].sum(), df ['shampoo'].sum(), df ['moisturizer'].sum()]
plt.axis("equal")
plt.pie(salesData, labels=labels, autopct='%1.1f%%')
plt.legend(loc='lower right')
plt.title('Sales data')
plt.show()

# %% [markdown]
# ## Exercise 9
# **Read Bathing soap facewash of all months and display it using the Subplot**
#
# **Expected output**
#
# <img src="../data/Sales_data_of_a_facewash.png" alt="Sales_data_of_a_facewash" style="width: 700px;"/>

# %%
# write your code here
fig = plt.figure(figsize =(7, 9))

plt.subplot(2, 1, 1)

plt.plot(data['month_number'], data['bathingsoap'], color='black', marker='o', linewidth=3)
plt.title('Sales data of  a Bathingsoap')

plt.subplot(2, 1, 2)
plt.plot(data['month_number'], data['facewash'], color='red', marker='o', linewidth=3)
plt.title('Sales data of  a facewash')

plt.xlabel('Month Number')
plt.ylabel('Sales units in number')
plt.show()

# %% [markdown]
# ## Exercise 10
# **Read all product sales data and show it using the stack plot**
#
# **Expected output**
#
# <img src="../data/product_sales_stack_plot.png" alt="product_sales_stack_plot" style="width: 700px;"/>

# %%
# write your code here
fig = plt.figure(figsize =(7, 7))

labels = ['FaceCream', 'FaseWash', 'ToothPaste','Bathing soap', 'Shampoo', 'Moisturizer']
plt.stackplot(data['month_number'], data['facecream'], data['facewash'], data['toothpaste'], data['bathingsoap'], data['shampoo'], data['moisturizer'], labels=labels)
plt.legend(loc = 'upper left')
plt.title('Alll product sales data using stack plot')
plt.xlabel('Month Number')
plt.ylabel('Sales unints in Number')
# Out:
# Text(0, 0.5, 'Sales unints in Number')
